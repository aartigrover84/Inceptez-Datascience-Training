# %% [markdown]
# Import the pandas library
# Read the data company.csv in pandas

# %%
import pandas as pd

# %%
compdata = pd.read_csv("/Users/anilsharma/Aarti/Datascience-training/week-3-4Jul2021/company.csv")

# %% [markdown]
# Find the dimension of given data

# %%
compdata.shape
# Out:
# (148, 6)

# %% [markdown]
# List down all the columns in data frame

# %%
compdata.columns
# Out:
# Index(['Company', 'Age', 'Salary', 'Place', 'Country', 'Gender'], dtype='object')

# %%
# Out:
# Index(['Company', 'Age', 'Salary', 'Place', 'Country', 'Gender'], dtype='object')

# %% [markdown]
# List the top 10 rows in datframe

# %%
compdata.head(10)
# Out:
#    Company   Age  Salary     Place Country  Gender
# 0      TCS  20.0     NaN   Chennai   India       0
# 1  Infosys  30.0     NaN    Mumbai   India       0
# 2      TCS  35.0  2300.0  Calcutta   India       0
# 3  Infosys  40.0  3000.0     Delhi   India       0
# 4      TCS  23.0  4000.0    Mumbai   India       0
# 5  Infosys   NaN  5000.0  Calcutta   India       0
# 6      TCS   NaN  6000.0   Chennai   India       1
# 7  Infosys  23.0  7000.0    Mumbai   India       1
# 8      TCS  34.0  8000.0  Calcutta   India       1
# 9      CTS  45.0  9000.0     Delhi   India       0

# %%
# Out:
#    Company   Age  Salary     Place Country  Gender
# 0      TCS  20.0     NaN   Chennai   India       0
# 1  Infosys  30.0     NaN    Mumbai   India       0
# 2      TCS  35.0  2300.0  Calcutta   India       0
# 3  Infosys  40.0  3000.0     Delhi   India       0
# 4      TCS  23.0  4000.0    Mumbai   India       0

# %% [markdown]
# List the last 15 rows in datframe

# %%
compdata.tail(15)
# Out:
#                        Company   Age  Salary      Place Country  Gender
# 133                        NaN  22.0  8943.0    Chennai   India       0
# 134  Tata Consultancy Services  31.0  8345.0     Mumbai   India       0
# 135                        CTS  40.0  9284.0   Calcutta   India       1
# 136                        NaN   NaN     NaN      Delhi   India       0
# 137                        CTS  31.0  2034.0     Mumbai   India       0
# 138                        CTS  44.0  3033.0     Cochin   India       0
# 139                 Congnizant  22.0  2934.0      Noida   India       0
# 140                    Infosys  44.0  4034.0  Hyderabad   India       0
# 141                        TCS  33.0  5034.0   Calcutta   India       0
# 142            Infosys Pvt Lmt  22.0  8202.0     Mumbai   India       0
# 143                        TCS  33.0  9024.0   Calcutta   India       1
# 144                    Infosys  22.0  8787.0   Calcutta   India       1
# ...

# %%
# Out:
#                        Company   Age  Salary      Place Country  Gender
# 133                        NaN  22.0  8943.0    Chennai   India       0
# 134  Tata Consultancy Services  31.0  8345.0     Mumbai   India       0
# 135                        CTS  40.0  9284.0   Calcutta   India       1
# 136                        NaN   NaN     NaN      Delhi   India       0
# 137                        CTS  31.0  2034.0     Mumbai   India       0
# 138                        CTS  44.0  3033.0     Cochin   India       0
# 139                 Congnizant  22.0  2934.0      Noida   India       0
# 140                    Infosys  44.0  4034.0  Hyderabad   India       0
# 141                        TCS  33.0  5034.0   Calcutta   India       0
# 142            Infosys Pvt Lmt  22.0  8202.0     Mumbai   India       0
# 143                        TCS  33.0  9024.0   Calcutta   India       1
# 144                    Infosys  22.0  8787.0   Calcutta   India       1
# ...

# %% [markdown]
# Find the number of rows in dataframe

# %%
compdata.shape[0]
# Out:
# 148

# %%
# Out:
# 148

# %% [markdown]
# Check the information of dataframe

# %%
compdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148 entries, 0 to 147
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Company  140 non-null    object
#  1   Age      130 non-null    float64
#  2   Salary   124 non-null    float64
#  3   Place    134 non-null    object
#  4   Country  148 non-null    object
#  5   Gender   148 non-null    int64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 7.1+ KB

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148 entries, 0 to 147
# Data columns (total 6 columns):
# Company    140 non-null object
# Age        130 non-null float64
# Salary     124 non-null float64
# Place      134 non-null object
# Country    148 non-null object
# Gender     148 non-null int64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 7.0+ KB

# %% [markdown]
# Check the basic Statistics of Dataframe. Give your inference from the stats

# %%
compdata.describe()
# Out:
#               Age       Salary      Gender
# count  130.000000   124.000000  148.000000
# mean    30.484615  5312.467742    0.222973
# std     11.096640  2573.764683    0.417654
# min      0.000000  1089.000000    0.000000
# 25%     22.000000  3030.000000    0.000000
# 50%     32.500000  5000.000000    0.000000
# 75%     37.750000  8000.000000    0.000000
# max     54.000000  9876.000000    1.000000

# %%
# Out:
#               Age       Salary      Gender
# count  130.000000   124.000000  148.000000
# mean    30.484615  5312.467742    0.222973
# std     11.096640  2573.764683    0.417654
# min      0.000000  1089.000000    0.000000
# 25%     22.000000  3030.000000    0.000000
# 50%     32.500000  5000.000000    0.000000
# 75%     37.750000  8000.000000    0.000000
# max     54.000000  9876.000000    1.000000

# %% [markdown]
# Retrieve 20 to 100 rows and Company and age usig iloc

# %%
compdata.iloc[20:100,0:2]
# Out:
#     Company   Age
# 20      TCS  37.0
# 21  Infosys  50.0
# 22      TCS  21.0
# 23  Infosys   NaN
# 24      TCS   NaN
# ..      ...   ...
# 95  Infosys   NaN
# 96      TCS   NaN
# 97  Infosys  22.0
# 98      TCS  33.0
# 99      CTS  44.0
#
# [80 rows x 2 columns]

# %% [markdown]
# Retrieve 20 to 100 rows and Company and age usig loc

# %%
# Out:
#      Company   Age
# 20       TCS  37.0
# 21   Infosys  50.0
# 22       TCS  21.0
# 23   Infosys   NaN
# 24       TCS   NaN
# 25   Infosys  23.0
# 26       TCS  34.0
# 27       CTS  45.0
# 28       CTS  23.0
# 29       CTS  35.0
# 30       CTS  46.0
# 31       CTS  20.0
# 32   Infosys  45.0
# 33       TCS  36.0
# 34   Infosys  26.0
# 35       TCS  35.0
# 36       TCS  32.0
# 37       NaN  35.0
# 38       TCS  34.0
# 39   Infosys  41.0
# 40       TCS  24.0
# 41   Infosys   NaN
# 42       TCS   NaN
# 43   Infosys  25.0
# 44       TCS  35.0
# 45       CTS  46.0
# 46       CTS  24.0
# 47       CTS  32.0
# 48       CTS  43.0
# 49       CTS  19.0
# ..       ...   ...
# 71       TCS  34.0
# 72       TCS  24.0
# 73   Infosys  34.0
# 74       TCS  37.0
# 75   Infosys  44.0
# 76       TCS  32.0
# 77   Infosys   NaN
# 78       TCS   NaN
# 79   Infosys  26.0
# 80       TCS  32.0
# 81       CTS  43.0
# 82       CTS  22.0
# 83       CTS  33.0
# 84       CTS  43.0
# 85       CTS  17.0
# ...

# %% [markdown]
# Chage the data in 100 row and Place as 'Noida'

# %%
compdata.loc[100,'Place']
# Out:
# 'Cochin'

# %%
compdata.loc[100,'Place'] = 'Noida'

# %%
compdata.loc[100]
# Out:
# Company      CTS
# Age           22
# Salary       NaN
# Place      Noida
# Country    India
# Gender         0
# Name: 100, dtype: object

# %%
# Out:
# Company      CTS
# Age           22
# Salary       NaN
# Place      Noida
# Country    India
# Gender         0
# Name: 100, dtype: object

# %% [markdown]
# Change the column 'Place' to 'City'

# %%
compdata.rename(columns={'Place':'City'}, inplace=True)

# %%
compdata.columns
# Out:
# Index(['Company', 'Age', 'Salary', 'City', 'Country', 'Gender'], dtype='object')

# %% [markdown]
# List down the unique data in each columns and find length of unique data

# %%
compdata.nunique()
# Out:
# Company     6
# Age        29
# Salary     40
# Place      11
# Country     1
# Gender      2
# dtype: int64

# %%
# Out:
# Company     6
# Age        29
# Salary     40
# City       11
# Country     1
# Gender      2
# dtype: int64

# %%
compdata['Company'].value_counts()
# Out:
# TCS                          53
# Infosys                      45
# CTS                          36
# Congnizant                    2
# Infosys Pvt Lmt               2
# Tata Consultancy Services     2
# Name: Company, dtype: int64

# %%
# Out:
# TCS                          53
# Infosys                      45
# CTS                          36
# Congnizant                    2
# Tata Consultancy Services     2
# Infosys Pvt Lmt               2
# Name: Company, dtype: int64
# 22.0    16
# 33.0    13
# 44.0    10
# 21.0     8
# 23.0     8
# 34.0     8
# 32.0     7
# 35.0     6
# 0.0      6
# 41.0     5
# 43.0     4
# 24.0     4
# 45.0     4
# 25.0     3
# 36.0     3
# 40.0     3
# 31.0     3
# 20.0     3
# 30.0     2
# 26.0     2
# 37.0     2
# 46.0     2
# 50.0     2
# 18.0     1
# 17.0     1
# 38.0     1
# 19.0     1
# 51.0     1
# 54.0     1
# Name: Age, dtype: int64
# 3000.0    9
# 5000.0    6
# 4034.0    5
# 8202.0    5
# 5034.0    5
# 3184.0    4
# 7084.0    4
# 8787.0    4
# 1234.0    4
# 3045.0    4
# 5835.0    4
# 9024.0    4
# 8943.0    4
# 9284.0    4
# 2034.0    4
# 4824.0    4
# 2934.0    4
# 1089.0    4
# 2300.0    4
# 8345.0    4
# 7000.0    3
# 3030.0    3
# 8000.0    3
# 9000.0    3
# 6000.0    3
# ...

# %% [markdown]
# Rename all the possible labels of column in Company as three labels
# TCS
# CTS
# Infosys

# %%
compdata.replace(to_replace="Tata Consultancy Services", value="TCS", inplace=True)

# %%
compdata.replace(to_replace="Infosys Pvt Lmt", value="Infosys", inplace=True)
compdata.replace(to_replace="Congnizant", value="CTS", inplace=True)

# %%
compdata['Company'].value_counts()
# Out:
# TCS        55
# Infosys    47
# CTS        38
# Name: Company, dtype: int64

# %% [markdown]
# Where ever you see age as 0 replace with NA
#
# ##Hint df[df.Age==20] = np.isnan

# %%
import numpy as np

# %%
compdata[compdata.Age==0] = np.isnan

# %%
compdata[compdata.Age==0]
# Out:
# Empty DataFrame
# Columns: [Company, Age, Salary, City, Country, Gender]
# Index: []

# %%
compdata.Age.isna().sum()
# Out:
# 18

# %% [markdown]
# Check how many duplicated data is there?

# %%
compdata[compdata.duplicated()].shape[0]
# Out:
# 9

# %%
# Out:
# 9

# %% [markdown]
# Remove all duplicated rowise data

# %%
compdata.drop_duplicates(inplace=True)

# %%
compdata.shape
# Out:
# (139, 6)

# %%
compdata
# Out:
#      Company Age Salary      City Country Gender
# 0        TCS  20    NaN   Chennai   India      0
# 1    Infosys  30    NaN    Mumbai   India      0
# 2        TCS  35   2300  Calcutta   India      0
# 3    Infosys  40   3000     Delhi   India      0
# 4        TCS  23   4000    Mumbai   India      0
# ..       ...  ..    ...       ...     ...    ...
# 142  Infosys  22   8202    Mumbai   India      0
# 143      TCS  33   9024  Calcutta   India      1
# 145  Infosys  44   4034     Delhi   India      1
# 146      TCS  33   5034    Mumbai   India      1
# 147  Infosys  22   8202    Cochin   India      0
#
# [139 rows x 6 columns]

# %% [markdown]
# Remove the column 'Country'

# %%
compdata.drop(columns={"Country"})
# Out:
#      Company Age Salary      City Gender
# 0        TCS  20    NaN   Chennai      0
# 1    Infosys  30    NaN    Mumbai      0
# 2        TCS  35   2300  Calcutta      0
# 3    Infosys  40   3000     Delhi      0
# 4        TCS  23   4000    Mumbai      0
# ..       ...  ..    ...       ...    ...
# 142  Infosys  22   8202    Mumbai      0
# 143      TCS  33   9024  Calcutta      1
# 145  Infosys  44   4034     Delhi      1
# 146      TCS  33   5034    Mumbai      1
# 147  Infosys  22   8202    Cochin      0
#
# [139 rows x 5 columns]

# %%
compdata
# Out:
#      Company Age Salary     Place Country Gender
# 0        TCS  20    NaN   Chennai   India      0
# 1    Infosys  30    NaN    Mumbai   India      0
# 2        TCS  35   2300  Calcutta   India      0
# 3    Infosys  40   3000     Delhi   India      0
# 4        TCS  23   4000    Mumbai   India      0
# ..       ...  ..    ...       ...     ...    ...
# 142  Infosys  22   8202    Mumbai   India      0
# 143      TCS  33   9024  Calcutta   India      1
# 145  Infosys  44   4034     Delhi   India      1
# 146      TCS  33   5034    Mumbai   India      1
# 147  Infosys  22   8202    Cochin   India      0
#
# [139 rows x 6 columns]

# %%
compdata
# Out:
#      Company  Age Salary        City Country Gender
# 0        TCS   20    NaN     Chennai   India      0
# 1    Infosys   30    NaN      Mumbai   India      0
# 2        TCS   35   2300    Calcutta   India      0
# 3    Infosys   40   3000       Delhi   India      0
# 4        TCS   23   4000      Mumbai   India      0
# 5    Infosys  NaN   5000    Calcutta   India      0
# 6        TCS  NaN   6000     Chennai   India      1
# 7    Infosys   23   7000      Mumbai   India      1
# 8        TCS   34   8000    Calcutta   India      1
# 9        CTS   45   9000       Delhi   India      0
# 10       CTS   23    NaN      Mumbai   India      0
# 11       CTS   34   1089    Calcutta   India      0
# 12       CTS   45    NaN     Chennai   India      0
# 13       CTS   18   1234      Mumbai   India      0
# 14   Infosys   40   3000    Calcutta   India      0
# 15       TCS   23   3000       Delhi   India      0
# 16   Infosys   23   3030  Podicherry   India      0
# ...

# %% [markdown]
# Remove the row number 137

# %%
compdata.drop(137, inplace=True)

# %%
compdata
# Out:
#      Company Age Salary      City Country Gender
# 0        TCS  20    NaN   Chennai   India      0
# 1    Infosys  30    NaN    Mumbai   India      0
# 2        TCS  35   2300  Calcutta   India      0
# 3    Infosys  40   3000     Delhi   India      0
# 4        TCS  23   4000    Mumbai   India      0
# ..       ...  ..    ...       ...     ...    ...
# 142  Infosys  22   8202    Mumbai   India      0
# 143      TCS  33   9024  Calcutta   India      1
# 145  Infosys  44   4034     Delhi   India      1
# 146      TCS  33   5034    Mumbai   India      1
# 147  Infosys  22   8202    Cochin   India      0
#
# [138 rows x 6 columns]

# %% [markdown]
# Find number of each labels in Company

# %%
compdata['Company'].value_counts()
# Out:
# TCS                52
# Infosys            43
# CTS                34
# <ufunc 'isnan'>     1
# Name: Company, dtype: int64

# %%
# Out:
# TCS                52
# Infosys            43
# CTS                35
# <ufunc 'isnan'>     1
# Name: Company, dtype: int64

# %% [markdown]
# Find number of each labels in City

# %%
compdata['City'].value_counts()
# Out:
# Mumbai             32
# Calcutta           30
# Delhi              13
# Chennai            13
# Cochin             12
# Noida               9
# Hyderabad           8
# Pune                2
# Podicherry          2
# <ufunc 'isnan'>     1
# Bhopal              1
# Nagpur              1
# Name: City, dtype: int64

# %%
# Out:
# Mumbai             33
# Calcutta           30
# Delhi              13
# Chennai            13
# Cochin             12
# Noida               9
# Hyderabad           8
# Podicherry          2
# Pune                2
# Nagpur              1
# <ufunc 'isnan'>     1
# Bhopal              1
# Name: City, dtype: int64

# %% [markdown]
# Find Number of Null Values in each column

# %%
compdata.isna().sum()
# Out:
# Company     8
# Age        17
# Salary     23
# City       14
# Country     0
# Gender      0
# dtype: int64

# %%
# Out:
# Company     8
# Age        17
# Salary     23
# City       14
# Country     0
# Gender      0
# dtype: int64

# %% [markdown]
# Remove all Null values in Salary

# %%
compdata.dropna(subset=['Salary'])
# Out:
#      Company  Age Salary      City Country Gender
# 2        TCS   35   2300  Calcutta   India      0
# 3    Infosys   40   3000     Delhi   India      0
# 4        TCS   23   4000    Mumbai   India      0
# 5    Infosys  NaN   5000  Calcutta   India      0
# 6        TCS  NaN   6000   Chennai   India      1
# ..       ...  ...    ...       ...     ...    ...
# 142  Infosys   22   8202    Mumbai   India      0
# 143      TCS   33   9024  Calcutta   India      1
# 145  Infosys   44   4034     Delhi   India      1
# 146      TCS   33   5034    Mumbai   India      1
# 147  Infosys   22   8202    Cochin   India      0
#
# [115 rows x 6 columns]

# %%
compdata['Salary'].isna().sum()
# Out:
# 0

# %%
compdata
# Out:
#      Company Age Salary      City Country Gender
# 0        TCS  20    NaN   Chennai   India      0
# 1    Infosys  30    NaN    Mumbai   India      0
# 2        TCS  35   2300  Calcutta   India      0
# 3    Infosys  40   3000     Delhi   India      0
# 4        TCS  23   4000    Mumbai   India      0
# ..       ...  ..    ...       ...     ...    ...
# 142  Infosys  22   8202    Mumbai   India      0
# 143      TCS  33   9024  Calcutta   India      1
# 145  Infosys  44   4034     Delhi   India      1
# 146      TCS  33   5034    Mumbai   India      1
# 147  Infosys  22   8202    Cochin   India      0
#
# [138 rows x 6 columns]

# %% [markdown]
# Replace the Null values in Comapany with mode

# %%
compdata['Company'].isna().sum()
# Out:
# 8

# %%
compdata[compdata['Company'].isna()]
# Out:
#     Company  Age Salary       City Country Gender
# 37      NaN   35    NaN  Hyderabad   India      0
# 51      NaN   24   3000     Mumbai   India      0
# 61      NaN   25   8943        NaN   India      1
# 64      NaN   25   6543      Noida   India      0
# 109     NaN   33    NaN   Calcutta   India      0
# 123     NaN  NaN   3454   Calcutta   India      0
# 133     NaN   22   8943    Chennai   India      0
# 136     NaN  NaN    NaN      Delhi   India      0

# %%
compdata['Company'].fillna(compdata['Company'].mode()[0], inplace=True)

# %%
compdata[compdata['Company'].isna()]
# Out:
# Empty DataFrame
# Columns: [Company, Age, Salary, City, Country, Gender]
# Index: []

# %% [markdown]
# Replace the null value in Salary with median

# %%
compdata['Salary'] = pd.to_numeric(compdata['Salary'], errors='coerce')

# %%
compdata['Salary']
# Out:
# 0         NaN
# 1         NaN
# 2      2300.0
# 3      3000.0
# 4      4000.0
#         ...
# 142    8202.0
# 143    9024.0
# 145    4034.0
# 146    5034.0
# 147    8202.0
# Name: Salary, Length: 138, dtype: float64

# %%
compdata['Salary'].fillna(compdata['Salary'].median(), inplace=True)

# %%
compdata["Salary"]
# Out:
# 0      5021.5
# 1      5021.5
# 2      2300.0
# 3      3000.0
# 4      4000.0
#         ...
# 142    8202.0
# 143    9024.0
# 145    4034.0
# 146    5034.0
# 147    8202.0
# Name: Salary, Length: 138, dtype: float64

# %% [markdown]
# Replace the null value in age with mean

# %%
compdata['Age'].isna().sum()
# Out:
# 17

# %%
compdata['Age'] = pd.to_numeric(compdata['Age'], errors='coerce')

# %%
compdata['Age'].fillna(compdata['Age'].mean(), inplace=True)

# %%
compdata['Age']
# Out:
# 0      20.0
# 1      30.0
# 2      35.0
# 3      40.0
# 4      23.0
#        ...
# 142    22.0
# 143    33.0
# 145    44.0
# 146    33.0
# 147    22.0
# Name: Age, Length: 138, dtype: float64

# %% [markdown]
# Filter the data with age>40 and Salary<5000

# %%
compdata
# Out:
#      Company   Age  Salary      City Country Gender
# 0        TCS  20.0  5021.5   Chennai   India      0
# 1    Infosys  30.0  5021.5    Mumbai   India      0
# 2        TCS  35.0  2300.0  Calcutta   India      0
# 3    Infosys  40.0  3000.0     Delhi   India      0
# 4        TCS  23.0  4000.0    Mumbai   India      0
# ..       ...   ...     ...       ...     ...    ...
# 142  Infosys  22.0  8202.0    Mumbai   India      0
# 143      TCS  33.0  9024.0  Calcutta   India      1
# 145  Infosys  44.0  4034.0     Delhi   India      1
# 146      TCS  33.0  5034.0    Mumbai   India      1
# 147  Infosys  22.0  8202.0    Cochin   India      0
#
# [138 rows x 6 columns]

# %%
compdata[(compdata.Age>40) & (compdata.Salary < 5000)]
# Out:
#      Company   Age  Salary       City Country Gender
# 21   Infosys  50.0  3184.0      Delhi   India      0
# 32   Infosys  45.0  4034.0   Calcutta   India      0
# 39   Infosys  41.0  3000.0     Mumbai   India      0
# 50   Infosys  41.0  3000.0    Chennai   India      0
# 57   Infosys  51.0  3184.0  Hyderabad   India      0
# 68   Infosys  43.0  4034.0     Mumbai   India      0
# 75   Infosys  44.0  3000.0     Cochin   India      0
# 86   Infosys  41.0  3000.0      Delhi   India      0
# 93   Infosys  54.0  3184.0     Mumbai   India      0
# 104  Infosys  44.0  4034.0      Delhi   India      0
# 122  Infosys  44.0  3234.0     Mumbai   India      0
# 129  Infosys  50.0  3184.0   Calcutta   India      0
# 138      CTS  44.0  3033.0     Cochin   India      0
# 140  Infosys  44.0  4034.0  Hyderabad   India      0
# 145  Infosys  44.0  4034.0      Delhi   India      1

# %%
# Out:
#      Company   Age  Salary       City Country Gender
# 21   Infosys  50.0  3184.0      Delhi   India      0
# 32   Infosys  45.0  4034.0   Calcutta   India      0
# 39   Infosys  41.0  3000.0     Mumbai   India      0
# 50   Infosys  41.0  3000.0    Chennai   India      0
# 57   Infosys  51.0  3184.0  Hyderabad   India      0
# 68   Infosys  43.0  4034.0     Mumbai   India      0
# 75   Infosys  44.0  3000.0     Cochin   India      0
# 86   Infosys  41.0  3000.0      Delhi   India      0
# 93   Infosys  54.0  3184.0     Mumbai   India      0
# 104  Infosys  44.0  4034.0      Delhi   India      0
# 122  Infosys  44.0  3234.0     Mumbai   India      0
# 129  Infosys  50.0  3184.0   Calcutta   India      0
# 138      CTS  44.0  3033.0     Cochin   India      0
# 140  Infosys  44.0  4034.0  Hyderabad   India      0
# 145  Infosys  44.0  4034.0      Delhi   India      1

# %% [markdown]
# Draw an histogram chart for age, Salary

# %%
# %matplotlib inline

# %%
compdata['Age'].plot(kind = 'hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
compdata['Salary'].plot(kind = 'hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# Draw the pie chart for place and Company

# %%
compdata.groupby(['Company']).sum().plot(kind="pie", subplots=True)
# Out:
# array([<AxesSubplot:ylabel='Age'>, <AxesSubplot:ylabel='Salary'>],
#       dtype=object)

# %% [markdown]
# Find the mean, count, median of salary with repective to the place

# %%
compdata.groupby('City').Salary.mean()
# Out:
# City
# <ufunc 'isnan'>    5021.500000
# Bhopal             7000.000000
# Calcutta           5099.750000
# Chennai            5638.961538
# Cochin             5053.000000
# Delhi              4940.307692
# Hyderabad          4542.500000
# Mumbai             5012.296875
# Nagpur             8000.000000
# Noida              4528.000000
# Podicherry         6157.000000
# Pune               7010.750000
# Name: Salary, dtype: float64

# %%
compdata.groupby('City').Salary.count()
# Out:
# City
# <ufunc 'isnan'>     1
# Bhopal              1
# Calcutta           30
# Chennai            13
# Cochin             12
# Delhi              13
# Hyderabad           8
# Mumbai             32
# Nagpur              1
# Noida               9
# Podicherry          2
# Pune                2
# Name: Salary, dtype: int64

# %%
compdata.groupby('City').Salary.median()
# Out:
# City
# <ufunc 'isnan'>    5021.50
# Bhopal             7000.00
# Calcutta           5010.75
# Chennai            5435.00
# Cochin             5017.00
# Delhi              4034.00
# Hyderabad          4517.00
# Mumbai             5021.50
# Nagpur             8000.00
# Noida              5021.50
# Podicherry         6157.00
# Pune               7010.75
# Name: Salary, dtype: float64

# %%
# Out:
#                         mean  count  median
# City
# <ufunc 'isnan'>  5009.000000      1  5009.0
# Bhopal           7000.000000      1  7000.0
# Calcutta         5115.400000     25  4824.0
# Chennai          5824.200000     10  5917.5
# Cochin           5053.000000     12  5017.0
# Delhi            4925.545455     11  4034.0
# Hyderabad        4382.833333      6  3609.0
# Mumbai           4895.269231     26  4429.0
# Nagpur           8000.000000      1  8000.0
# Noida            4387.000000      7  4000.0
# Podicherry       6157.000000      2  6157.0
# Pune             9000.000000      1  9000.0

# %% [markdown]
# Find the mean age with repective to the Company

# %%
compdata.groupby('Company').Age.mean()
# Out:
# Company
# <ufunc 'isnan'>    32.050000
# CTS                33.176471
# Infosys            33.775581
# TCS                30.175000
# Name: Age, dtype: float64

# %%
# Out:
# Company
# <ufunc 'isnan'>    32.292929
# CTS                33.160000
# Infosys            33.950013
# TCS                31.137901
# Name: Age, dtype: float64
